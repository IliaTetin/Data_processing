# %% [markdown]
# # Analytics for business and decision making (Fall 2023)
# ## Week 2 - Getting familiar with Python. Working with integers
# Author: Dr. Ilia Tetin

# %% [markdown]
# # Recap
# In Python, basic mathematical operations like addition (+), subtraction (−), multiplication (*), and division (/) are commonly used. However, for more advanced programming tasks, we often require additional operations. Some of these include:
#
#     Exponentiation (**)
#     Modulo operation (%)
#     Integer division (//)
#
# The exponentiation operator (**) is right-associative, meaning it evaluates from right to left, conforming to mathematical rules. For instance, the expression x ** y ** z is computed as $x^{(y^z)}$.

# %% [markdown]
# ## Example: Compound Interest
#
# In economics, the formula for compound interest is often represented as:
# $$ A = P\left(1+\frac{r}{n}\right)^{nt}$$
#
# $A$ is the money accumulated after n years, including interest.
# $P$ is the principal amount.
# $r$ is the annual interest rate (in decimal form).
# $n$ is the number of times that interest is compounded per year.
# $t$ is the time the money is invested for, in years.

# %% [markdown]
# In Python, the integer division operator (//) performs division and truncates the result to the nearest integer towards zero. Unlike the standard division operator (/), it discards the decimal part of the quotient.
#
# When dealing with negative numbers, it's important to note that the result of integer division is rounded towards the more negative number. In other words, it rounds "down," even when the number is negative.

# %% [markdown]
# The modulo operator (%) returns the remainder of the division between two integers. This operator is especially useful for a variety of programming and mathematical tasks.  When $n<m$, the result of `n%m` is $n$ itself

# %% [markdown]
# #### Task 1.10: Calculating Cube Dimensions
#
# Create a Python program that computes both the volume and the total surface area of a cube, given the length of one edge.
#
# **Input Data Format**
#
# The program should accept a single integer, representing the length of an edge of the cube.
#
# **Output Data Format**
#
# The program must output the calculated volume and total surface area, accompanied by relevant text to make the results explicit.
#
# Note: The formulas for calculating the volume $V$ and the total surface area $S$ of a cube are:
# $$ V=a^3, \, \, S=6a^2 $$
#
# **Sample Input 1:**
# ```
# 25
# ```
#
# **Sample Output 1:**
# ```
# Volume = 15625
# Total surface area = 3750
# ```

# %%
### Example

# %% [markdown]
# ## Working with integers

# %% [markdown]
# ### Example 1
# Write a program that calculates the sum, difference, and product of two integers entered from the keyboard.
#
# **Input data format**
# The input to the program is two integers, each on a separate line.
#
# **Output format.** The program should print the sum, difference, and product of the entered numbers, each on a separate line.
#
# **Sample Input 1 :**
# ```
# 2
# 7
# ```
# **Sample Output 1 :**
# ```
# 2 + 7 = 9
# 2 - 7 = -5
# 2 * 7 = 14
# ```

# %% [markdown]
# ### Example 2
# An arithmetic progression is a sequence of numbers $a_1, a_2, \dots, a_n$, calculated with the formula:
#
# $$a_n = a_{n+1} + d$$
#
# If the first term of the progression and its common ratio are known, then $n$-th member of the arithmetic progression is found by the formula:
#
# $$a_n = a_1 + d(n-1)$$
#
# **Input data**
# The program receives three integers as input: $a_1, d, n$
#
# **Output**
# The program should output $n$-th member of the arithmetic progression.
#
# **Sample Input 1:**
# ```
# 1
# 1
# 10
# ```
# **Sample Output 1 :**
# ```
# 10
# ```
# **Sample Input 2:**
# ```
# 100
# 50
# 1
# ```
# **Sample Output 2:**
# ```
# 100
# ```

# %% [markdown]
# ### Task 2.1
# A geometric progression is a sequence of numbers $b_1, b_2, \dots, b_n$, calcu.ated with a formula
# $$b_n = b_{n-1} \times q$$
# If the first term of the progression and its common ratio are known, then $n n$-th member of the geometric progression is found by the formula
# $$b_n = b_1 \times q^{n-1}$$
# **Input data**
# The program receives three integers as input: $b_1, q, n$
#
# **Output**
# The program should output $n$-th member of the geometric progression.
#
# **Sample Input**
# ```
# 1
# 2
# 5
# ```
# **Sample Output**
# ```
# 16
# ```

# %%
### YOUR CODE HERE

# %% [markdown]
# ### Task 2.2
# Mad Titan Thanos has acquired all six Infinity Stones. His intent is to reduce the universal population by half with a simple snap of his fingers. Importantly, if the total population of the universe is an odd number, Thanos will opt for leniency by rounding the number of survivors up to the nearest whole number. This task aims to assist the Avengers in computing the number of survivors.
#
# **Input data format**
# The input consists of an integer $n$, which represents the total population of the universe.
#
# **Output format**
# The program should print a single number - the number of survivors.
#
# **Sample Input 1 :** `99`
#
# **Sample Output 1 :** `50`
#
# **Sample Input 2 :** `1132`
#
# **Sample Output 2 :** `566`
#
# **Sample Input 3 :** `1`
#
# **Sample Output 3 :** `1`

# %%
### YOUR CODE HERE

# %% [markdown]
# ### Example 3
#
# The objective of this program is to convert a given time interval, initially presented in minutes, to a format denoting the equivalent duration in hours and minutes.
#
# **Input data format**
# The input for this program is an integer representing the time interval in minutes.
#
# **Output format**
# The program should output text that accurately reflects the conversion from minutes to hours and minutes, following the problem's guidelines.
#
# **Sample Input 1  :** `150 `
#
# **Sample Output 1 :** `150 minutes = 2 hours and 30 minutes.`
#
# **Sample Input 2  :** `50`
#
# **Sample Output 2 :** `50 minutes = 0 hours 50 minutes.`
#
# **Sample Input 3  :** `240`
#
# **Sample Output 3 :** `240 minutes = 4 hours 0 minutes.`

# %% [markdown]
# ## Extracting Digits from a Number using Remainder and Integer Division Operations
#
# The remainder and integer division operations facilitate the extraction of individual digits from a numerical value.
#
# **Two-Digit Number Example**
#
# For a two-digit number num=17, the following program can be used to obtain its digits:

# %% [markdown]
# That is, first we deduced the last digit of the number, and then the first digit.
#
# Remember: the last digit of a number is always defined as the remainder of dividing the number by `10 (% 10).` To split off the last digit from a number, you need to divide it entirely by `10 (// 10).`
#
# **Three-Digit Number Example**
#
# For a three-digit number num=754 the following program extracts its digits:

# %% [markdown]
# Here, the last digit is first extracted, followed by the middle digit, and finally, the first digit is obtained.

# %% [markdown]
# ### Algorithm for obtaining numbers $n$-significant number
#
# It is easy to understand by what algorithm you can find each digit $n$ -significant number $num$:
#
#
# `Last digit: (num % 10 ** 1) // 10 ** 0`;
#
# `Last - 1 digit: (num % 10 ** 2) // 10 ** 1`;
#
# `Last - 2 digit: (num % 10 ** 3) // 10 ** 2`;
#
# `.....`
#
# `Second digit: (num % 10 ** (n-1)) // 10 ** (n-2)`;
#
# `First digit: (num % 10 ** (n)) // 10 ** (n-1)`.

# %% [markdown]
# ### Examples for digits processing

# %% [markdown]
# ### Example 4.
# Write a program that determines the number of tens and ones in a two-digit number.
#
# **Solution.** The number of units is the last digit, and the number of tens is the first. To get the last digit of any number, you need to find the remainder by dividing the number by 10. To find the first digit of a two-digit number, you need to divide the number by 10. The program that solves the problem might look like this:

# %% [markdown]
# ### Example 5.
# Write a program that calculates the sum of the digits of a two-digit number.
#
# **Solution**. The program that solves the problem may look like this:

# %% [markdown]
# ### Example 6.
# Write a program that prints the number formed by permuting the digits of a two-digit number.
#
# **Solution.** The program that solves the problem may look like this:

# %% [markdown]
# ### Example 7.
# Write a program into which a three-digit number is entered and which displays its digits (separated by commas).
#
# **Solution.** The program that solves the problem may look like this:

# %% [markdown]
# ### Task 4 Computing the Sum and Product of Digits for a Positive Three-Digit Number
# Write a program that calculates the sum and product of the digits of a positive three-digit number.
#
# **Input data format**
# The program takes a positive three-digit integer as its input.
#
# **Output format**
# The output should include two lines of text, each accompanied by a numerical value: the first line should display the sum of the digits, and the second line should display the product of the digits.
#
# **Sample Input 1 :**
# `123 `
#
# **Sample Output 1 :**
# ```
# Sum of digits = 6
# Product of digits = 6
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 5 Generating Permutations of Digits for a Distinct Three-Digit Number
# The goal of this task is to create a program that generates all possible permutations of the digits of a given positive three-digit number ```abc```, assuming each digit is distinct.
#
# **Input data format**
# The program should accept a positive three-digit integer as its input, with the stipulation that all digits must be unique.
#
# **Output format**
# The program should output the six numbers formed by permuting the digits of the given number. These numbers should be displayed in the following order:
#
# **Sample input 1:** `123`
#
# **Sample Output 1 :**
# ```
# 123
# 132
# 213
# 231
# 312
# 321
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 6 Extracting Digits from a Positive Four-Digit Number
# The objective of this task is to write a program that identifies and displays the digits of a given positive four-digit number, categorized by their respective positions.
#
# **Input data format**
# The input for the program should be a positive four-digit integer.
#
# **Output format**
# The program should output text that delineates the digits of the given number, identifying their positions as thousands, hundreds, tens, or units.
#
# **Sample Input 1 :** `3281`
#
# **Sample Output 1 :**
# ```
# The number in the thousands position is 3
# The digit in the hundreds position is 2
# The digit in the tens position is 8
# The digit in the units position is 1
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Working with Floating-Point Numbers in Python

# %% [markdown]
# ### Floating point numbers
# In addition to integers, Python also supports arithmetic operations with fractional or real numbers. For instance, numbers like $\frac{2}{3}, \sqrt{2}, and \pi$ are real numbers and cannot be adequately represented using the integer data type *int*
#
# In computer science, these fractional or real numbers are referred to as **floating-point numbers**. Python employs the data type *float* to handle these numbers.
#
# To convert a string to a floating point number, we use the command `float():`
# `num = float(input())`
#
# The following code converts the string 1.2345 to a floating point number:
# `n = float('1.2345')`

# %%
n = float('1.2345')
print(n)

# %% [markdown]
# ### Converting between int and float
#
# Implicit conversion. Any integer (type int) can be used where a floating point number is expected (type float) because Python will automatically convert integers to floats when necessary.
#
# Explicit conversion. A floating point number cannot be implicitly converted to an integer. For such a conversion, you must use an explicit conversion using the command int().

# %%
num1 = 17.89
num2 = -13.56
num3 = int(num1)
num4 = int(num2)
print(num3)
print(num4)

# %% [markdown]
# Please note that the conversion of floating point numbers to an integer is done with rounding towards zero, that is
#
# `int(1.7) = 1, int(-1.7) = -1. `
#
# Do not confuse the conversion and rounding operations. Additional commands are used to round floating point numbers.
#
# #### Note
#
# Beginning programmers often find the need for type conversion annoying, but experienced programmers know that attention to data types is the key to success and a way to avoid mistakes. In 1996, a French rocket exploded mid-air due to a type conversion problem. Although a bug in your program might not cause an explosion, it's still worth learning about type conversion. Having written several programs, you will see that understanding data types helps to write compact code and clearly state your intentions, avoiding mistakes in nuances.
#
#
# ![image.png](data:image/png;base64,...)
#
# Figure: The crash of the French rocket "Ariane-5"

# %% [markdown]
# ### Example 8
# Given a positive real number. Print its first digit after the decimal point.
#
# **Input data format**
#
# The input to the program is a positive real number.
#
# **Output format**
#
# The program should display the number in accordance with the condition of the problem.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 7
# Given a positive real number. Print its fractional part.
#
# Input data format
# The input to the program is a positive real number.
#
# Output format
# The program should display the fractional part of the number in accordance with the condition of the problem.
#
# **Sample Input 1 :** `44.45`
#
# **Sample Output 1 :** `0.45`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 8
# Write a program that reads the lengths of two legs in a right triangle and prints its area.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# **Input data format**
# The input to the program is two floating-point numbers - the lengths of the legs, each on a separate line.
#
# **Output format**
# The program should output one number - the area of ​​the triangle.
#
# **Sample Input 1 :**
# ```
# 32.2
# 25.5
# ```
#
# **Sample Output 1 :**
# ```
# 410.55
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 9
# Inspired by the renowned American writer Ray Bradbury's novel "Fahrenheit 451," this task aims to create a program that converts a given temperature from the Fahrenheit scale to its equivalent on the Celsius scale. Utilize the following formula for the conversion: $$C = \frac{5}{9}\left(F - 32\right)$$
#
# **Input data format**
# The input for this program should be a real number representing the temperature in degrees Fahrenheit.
#
# **Output format**
# The program should output a real number indicating the corresponding temperature in degrees Celsius.
#
# **Sample Input 1 :** `275.0`
#
# **Sample Output 1 :** `135.0`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 10 Calculating Manhattan Distance in a Grid-Based Layout
# In Manhattan, the urban grid restricts direct paths between two points. Unless one possesses the ability to phase through walls, the journey will inevitably follow the grid's parallel and perpendicular streets. The Manhattan distance between two points $(p_1;p_2)$ and $(q_1;q_2)$ on such a grid can be calculated using the following formula: $$D(p_1;p_2), (q_1; q_2) = |p_1-q_1| + |p_2-q_2|$$
#
# **Input data format**
# The program should accept four floating-point numbers as input.
#
# **Output format**
# The program should output a single number representing the Manhattan distance between the two points.
#
# **Sample Input:**
# ```
# 10
# 15
# 21
# 13
# ```
# **Sample Output:** `13`
#
#
#
#
# ![image.png](data:image/png;base64,...)
